# %%
import xml.etree.ElementTree as ET
tree = ET.parse( "SimpleGifts.mscx" )
root = tree.getroot()

# %%
class Measure:
    def __init__( self ):
        self.chords = []
        #print( "Created new measure." )
                
    def __str__( self ):
        if ( len( self.chords ) != 0):
            return_string = ""
            for i in self.chords:
                return_string += str(i) + "\n"
                
            return_string += "End measure"
        else:
            return_string = "Empty measure"
        return return_string
    
class Chord:
    def __init__( self ):
        self.duration = None
        self.notes = []
        #print( "Created new chord." )
    
    def __str__( self ):
        return_string = "Chord with duration of " + self.duration + "\n"
        for i in self.notes:
            return_string += str(i)
        return return_string
    
class Note:
    def __init__( self ):
        self.pitch = None
        self.tpc = None
        #print(" Created new note." )
        
    def __str__( self ):
        return_string = "Note with pitch of " + self.pitch + " and TPC of " + self.tpc
        return return_string

# %%
measures = []
print(list(root))
#for child in root:
#    print (child.tag, child.attrib)
score = root[2]
#print(list(score))
current_measure = -1
for staff in score:
    #print (staff.tag, staff.attrib
    if( staff.tag == "Staff" ):
        for measure in staff:
            current_measure += 1
            current_chord = -1
            measures.append(Measure())
            #print( "\t", measure.tag, measure.attrib )
            nv = 1
            
            for voice in measure:
                nv += 1
                #print( "\t\t", voice.tag, voice.attrib )
                
                for child in voice:
                    is_chord = False
                    
                    if( child.tag == "Chord" ):
                        current_chord += 1
                        current_note = -1
                        is_chord = True
                        measures[ current_measure ].chords.append(Chord())
                    #print( "\t\t\t", child.tag, child.attrib )
                    
                    for gchild in child:
                        is_note = False
                        if ( is_chord ):
                            if( gchild.tag == "durationType" ):
                                measures[ current_measure ].chords[ current_chord ].duration = gchild.text
                            elif ( gchild.tag == "Note" ):
                                measures[ current_measure ].chords[ current_chord ].notes.append(Note())
                                is_note = True
                                current_note += 1
                                
                        #print( "\t\t\t\t", gchild.tag, gchild.attrib, gchild.text )
                        for ggchild in gchild:
                            if ( is_note ):
                                if( ggchild.tag == "pitch" ):
                                    measures[
                                        current_measure ].chords[
                                        current_chord ].notes[
                                        current_note ].pitch = ggchild.text
                                elif (ggchild.tag == "tpc" ):
                                    measures[
                                        current_measure ].chords[
                                        current_chord ].notes[
                                        current_note ].tpc = ggchild.text
            
                            #print( "\t\t\t\t\t", ggchild.tag, ggchild.attrib, ggchild.text )
                            
        #print( "End Staff" )
# Out:
# [<Element 'programVersion' at 0x7fb1c14a1318>, <Element 'programRevision' at 0x7fb1c14a1908>, <Element 'Score' at 0x7fb1c0c44318>]

# %%
print(len(measures), "measures")
for i in measures:
    print(i)
# Out:
# 121 measures
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Chord with duration of quarter
# Note with pitch of 74 and TPC of 16
# End measure
# Chord with duration of half
# Note with pitch of 79 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 81 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 79 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 78 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 79 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 76 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 74 and TPC of 16
# Chord with duration of half
# Note with pitch of 71 and TPC of 19
# End measure
# Chord with duration of half
# Note with pitch of 74 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 78 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 76 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 74 and TPC of 16
# End measure
# Chord with duration of eighth
# Note with pitch of 81 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 79 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 78 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 76 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 78 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 76 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# End measure
# Chord with duration of half
# Note with pitch of 79 and TPC of 15
# Chord with duration of half
# Note with pitch of 74 and TPC of 16
# End measure
# Chord with duration of half
# Note with pitch of 81 and TPC of 17
# Chord with duration of half
# Note with pitch of 74 and TPC of 16
# End measure
# Chord with duration of eighth
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 71 and TPC of 19
# Chord with duration of quarter
# Note with pitch of 74 and TPC of 16
# End measure
# Chord with duration of quarter
# Note with pitch of 67 and TPC of 15
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of half
# Note with pitch of 71 and TPC of 19
# End measure
# Chord with duration of half
# Note with pitch of 78 and TPC of 20
# Chord with duration of half
# Note with pitch of 79 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 76 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# End measure
# Chord with duration of half
# Note with pitch of 74 and TPC of 16
# Chord with duration of half
# Note with pitch of 79 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 81 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 78 and TPC of 20
# Chord with duration of half
# Note with pitch of 79 and TPC of 15
# End measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Empty measure
# Chord with duration of quarter
# Note with pitch of 62 and TPC of 16
# End measure
# Chord with duration of quarter
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# End measure
# Chord with duration of quarter
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of quarter
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# End measure
# Chord with duration of quarter
# Note with pitch of 67 and TPC of 15
# Chord with duration of quarter
# Note with pitch of 64 and TPC of 18
# Chord with duration of half
# Note with pitch of 67 and TPC of 15
# End measure
# Chord with duration of half
# Note with pitch of 74 and TPC of 16
# Chord with duration of half
# Note with pitch of 71 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of half
# Note with pitch of 67 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of quarter
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of quarter
# Note with pitch of 67 and TPC of 15
# Chord with duration of quarter
# Note with pitch of 62 and TPC of 16
# End measure
# Chord with duration of quarter
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# End measure
# Chord with duration of quarter
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of quarter
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# End measure
# Chord with duration of quarter
# Note with pitch of 67 and TPC of 15
# Chord with duration of quarter
# Note with pitch of 64 and TPC of 18
# Chord with duration of half
# Note with pitch of 67 and TPC of 15
# End measure
# Chord with duration of half
# Note with pitch of 74 and TPC of 16
# Chord with duration of half
# Note with pitch of 71 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of half
# Note with pitch of 67 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of quarter
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 62 and TPC of 16
# End measure
# Chord with duration of quarter
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# End measure
# Chord with duration of quarter
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of quarter
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# End measure
# Chord with duration of quarter
# Note with pitch of 67 and TPC of 15
# Chord with duration of quarter
# Note with pitch of 64 and TPC of 18
# Chord with duration of half
# Note with pitch of 67 and TPC of 15
# End measure
# Chord with duration of half
# Note with pitch of 74 and TPC of 16
# Chord with duration of half
# Note with pitch of 71 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of half
# Note with pitch of 67 and TPC of 15
# End measure
# Empty measure
# Chord with duration of eighth
# Note with pitch of 81 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 79 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 78 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 76 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# End measure
# Chord with duration of eighth
# Note with pitch of 67 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 69 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 72 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 71 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 74 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 79 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 83 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 81 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 78 and TPC of 20
# Chord with duration of half
# Note with pitch of 79 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of half
# Note with pitch of 55 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 57 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of half
# Note with pitch of 55 and TPC of 15
# End measure
# Empty measure
# Empty measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of half
# Note with pitch of 43 and TPC of 15
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# End measure
# Chord with duration of quarter
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 54 and TPC of 20
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of quarter
# Note with pitch of 50 and TPC of 16
# Chord with duration of quarter
# Note with pitch of 47 and TPC of 19
# End measure
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 52 and TPC of 18
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# End measure
# Chord with duration of eighth
# Note with pitch of 43 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 45 and TPC of 17
# Chord with duration of eighth
# Note with pitch of 48 and TPC of 14
# Chord with duration of eighth
# Note with pitch of 47 and TPC of 19
# Chord with duration of eighth
# Note with pitch of 50 and TPC of 16
# Chord with duration of eighth
# Note with pitch of 55 and TPC of 15
# Chord with duration of eighth
# Note with pitch of 59 and TPC of 19
# End measure
# Chord with duration of quarter
# Note with pitch of 57 and TPC of 17
# Chord with duration of quarter
# Note with pitch of 54 and TPC of 20
# Chord with duration of half
# Note with pitch of 55 and TPC of 15
# End measure
